# %%
import selenium
import requests
import numpy as np
import pandas as pd
from selenium import webdriver
# from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
def MostViewed():
    
    Url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
    
    driver = webdriver.Chrome() 
    driver.get(Url) 
    driver.maximize_window() 
    
    details = [] 
    
    for i in driver.find_elements(By.XPATH,"//table [@class = 'wikitable sortable jquery-tablesorter']/tbody/tr/td"):
        details.append(i.text)
        
    driver.close() 
    
    details= details[:180] 
    
    Rank = [] 
    Name = [] 
    Artist = [] 
    Views = [] 
    Upload_date = [] 

    z= 0
    while z < len(details): 
        Rank.append(details[z])
        z+=1
        Name.append(details[z])
        z+=1
        Artist.append(details[z])
        z+=1
        Views.append(details[z])
        z+=1
        Upload_date.append(details[z])
        z+=2
    
    table = pd.DataFrame({"Rank" : Rank,
                          "Name" : Name, 
                          "Artist" : Artist,
                          "Upload date" : Upload_date,
                          "Views" : Views
    })        
    
    
    return table

# %%
Most_Viewed = MostViewed()
Most_Viewed
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
Url = 'https://www.bcci.tv/'
driver = webdriver.Chrome()
driver.maximize_window()
driver.get(Url)

# %%
button=driver.find_element(By.XPATH,'//span[@class="navigation__search-open-icon"]')
button.click()

# %%
INTERNATIONAL = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
INTERNATIONAL.click()

# %%
Match_Title = []
Series = []
Place = []
Date = []
Time = []

match_title = driver.find_elements(By.XPATH,"//span[@class='ng-binding']")

for i in match_title:
    try:
        Match_Title.append(i.text)
    except NoSuchElementException:
        Match_Title.append("--")
        
series = driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')

for i in series:
    try:
        Series.append(i.text)
    except NoSuchElementException:
        Series.append("--")
        
place=driver.find_elements(By.XPATH,"//span[@class='ng-binding ng-scope']")
for i in place:
    if i.text is None:
        Place.append("--")
    else:
        Place.append(i.text)
        
date = driver.find_elements(By.XPATH,"//div[@class='match-card-left match-schedule']")
for i in date:
    if i.text is None:
        Date.append("--")
    else:
        Date.append(i.text)
        
time=driver.find_elements(By.XPATH,"//div[@class='match-card-right match-schedule ']")
for i in time:
    if i.text is None:
        Time.append("--")
    else:
        Time.append(i.text)
        
print(len(Match_Title))
print(len(Series))
print(len(Date))
print(len(Time))
print(len(Place))
# Out:
# 14
# 14
# 14
# 14
# 14

# %%
Data_2 = pd.DataFrame({'Match_Title':Match_Title,'Series':Series,'Date':Date,'Place':Place,'time':Time})
Data_2
# Out:
#                                       Match_Title      Series         Date  \
# 0          INDIA TOUR OF ZIMBABWE ODI SERIES 2022   1st ODI -  18 AUG 2022
# 1          INDIA TOUR OF ZIMBABWE ODI SERIES 2022   2nd ODI -  20 AUG 2022
# 2          INDIA TOUR OF ZIMBABWE ODI SERIES 2022   3rd ODI -  22 AUG 2022
# 3                                   ASIA CUP 2022  1st T20I -  28 AUG 2022
# 4                                   ASIA CUP 2022  2nd T20I -  31 AUG 2022
# 5         AUSTRALIA TOUR OF INDIA T20 SERIES 2022  1st T20I -  20 SEP 2022
# 6         AUSTRALIA TOUR OF INDIA T20 SERIES 2022  2nd T20I -  23 SEP 2022
# 7         AUSTRALIA TOUR OF INDIA T20 SERIES 2022  3rd T20I -  25 SEP 2022
# 8   SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23  1st T20I -  28 SEP 2022
# 9   SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23  2nd T20I -   2 OCT 2022
# 10  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23  3rd T20I -   4 OCT 2022
# ...

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
Url = 'https://www.guru99.com/'
driver = webdriver.Chrome()
driver.maximize_window()
driver.get(Url)

# %%
Search = driver.find_element(By.XPATH,'//ul[@id="java_technologies"]/li[3]/a').get_attribute('href')
driver.get(Search)

# %%
Input_Search = exc = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a').get_attribute('href')
driver.get(Input_Search)

# %%
Name=[]
Desc=[]
# fetching exception 
for i in range(2,13):
    # name
    Name_chk = driver.find_element(By.XPATH,'//table[@class="table table-striped"]/tbody/tr[{}]/td[1]'.format(i))
    Name.append(Name_chk.text)
    # description
    Desc_chk = driver.find_element(By.XPATH,'//table[@class="table table-striped"]/tbody/tr[{}]/td[2]'.format(i))
    Desc.append(Desc_chk.text)

# %%
Data_3=pd.DataFrame({'Name':Name,'Description':Desc})
Data_3
# Out:
#                               Name  \
# 0       ElementNotVisibleException
# 1    ElementNotSelectableException
# 2           NoSuchElementException
# 3             NoSuchFrameException
# 4          NoAlertPresentException
# 5            NoSuchWindowException
# 6   StaleElementReferenceException
# 7         SessionNotFoundException
# 8                 TimeoutException
# 9               WebDriverException
# 10       ConnectionClosedException
#
#                                           Description
# 0   This type of Selenium exception occurs when an...
# 1   This Selenium exception occurs when an element...
# 2   This Exception occurs if an element could not ...
# 3   This Exception occurs if the frame target to b...
# 4   This Exception occurs when you switch to no pr...
# 5   This Exception occurs if the window target to ...
# 6   This Selenium exception occurs happens when th...
# 7   The WebDriver is acting after you quit the bro...
# ...

# %% [markdown]
# Q4. Scrape the details of State-wise GDP of India from statisticstime.com. Url=http://statisticstimes.com/ You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP
#
# D) Share
#
# E) In GDP
#
# Note:-From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome()
driver.maximize_window()
Url = 'http://statisticstimes.com/'
driver.get(Url)

# %%
Economy = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
Economy.click()
India = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
India.click()

# %%
GDP_India_States = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
GDP_India_States.click()
time.sleep(2)

# %%
Rank = []
State = []
GSDP = []
Share = []
In_GDP = []

for i in range(1,32):
    
    rank = driver.find_element(By.XPATH,'//div[@class="dataTables_wrapper"]/table[1]/tbody/tr[{}]/td[1]'.format(i))
    Rank.append(rank.text)
    
    state = driver.find_element(By.XPATH,'//div[@class="dataTables_wrapper"]/table[1]/tbody/tr[{}]/td[2]'.format(i))
    State.append(state.text)
    
    gsdp = driver.find_element(By.XPATH,'//div[@class="dataTables_wrapper"]/table[1]/tbody/tr[{}]/td[3]'.format(i))
    GSDP.append(gsdp.text)
    
    gdp = driver.find_element(By.XPATH,'//div[@class="dataTables_wrapper"]/table[1]/tbody/tr[{}]/td[6]'.format(i))
    In_GDP.append(gdp.text)
    
    share = driver.find_element(By.XPATH,'//div[@class="dataTables_wrapper"]/table[1]/tbody/tr[{}]/td[5]'.format(i))
    Share.append(share.text)

# %%
Data_4 =pd.DataFrame({'Rank':Rank,'State':State,'GSDP(Cr in INR)(19-20)':GSDP,'Share':Share,'Gdp(in_billions)':In_GDP})
Data_4
# Out:
#    Rank              State GSDP(Cr in INR)(19-20)   Share Gdp(in_billions)
# 0     1        Maharashtra                      -  13.94%          399.921
# 1     2         Tamil Nadu              1,845,853   8.63%          247.629
# 2     3      Uttar Pradesh              1,687,818   8.39%          240.726
# 3     4            Gujarat                      -   7.96%          228.290
# 4     5          Karnataka              1,631,977   7.91%          226.806
# 5     6        West Bengal              1,253,832   5.77%          165.556
# 6     7          Rajasthan              1,020,989   4.99%          143.179
# 7     8     Andhra Pradesh                972,782   4.57%          131.083
# 8     9          Telangana                969,604   4.56%          130.791
# 9    10     Madhya Pradesh                906,672   4.29%          122.977
# 10   11             Kerala                      -   4.14%          118.733
# ...

# %% [markdown]
# Q5. Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code

# %%
driver = webdriver.Chrome()
driver.maximize_window()
Url = 'https://github.com/'
driver.get(Url)

# %%
try:
    Explore = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
    Explore.click()
except NoSuchElementException :
    print('No Explore Button')
time.sleep(2)

try:
    Trending = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
    Trending.click()
except NoSuchElementException:
    print('No Explore Button')
time.sleep(2)

# %%
Title=[]
Description=[]
Language=[]
List=[]
Contributor=[]

#scrapping title 
try:
    title=driver.find_elements(By.XPATH,"//span[@class='text-normal']")
    for i in title:
          Title.append(i.text)
except NoSuchElementException:
          Title.append("-")
  
#scrapping languages
Lists1=[]
lists1=driver.find_elements(By.XPATH,"//span[@class='d-inline-block ml-0 mr-3']//span")
for i in lists1:
    try:
        Lists1.append(i.text.split())
    except NoSuchElementException:
        Lists1.append('-')        

for i in range(1,len(Lists1),2):
        Language.append(Lists1[i])


 #scrapping description
try:
    desc=driver.find_elements(By.XPATH,"//article[@class='Box-row']//p")
    for i in desc:
          Description.append(i.text)
except NoSuchElementException:
          Description.append("--")



#scrapping Number of contributors
try:
    link=driver.find_elements(By.XPATH,"//a[@class='Link--muted d-inline-block mr-3']")
    for i in link:
          List.append(i.text)
except NoSuchElementException:
          List.append("--")
        
for i in range(0,len(List),2):
    try:
        Contributor.append(List[i])
    except NoSuchElementException:
        Contributor.append("--")

# %%
Data_5=pd.DataFrame({'Title':Title[:21],'Description':Description[:21],'Language':Language[:21],'List':List[:21],'Contributors':Contributor[:21]})
Data_5
# Out:
#                  Title                                        Description  \
# 0       toeverything /  There can be more than Notion and Miro. Affine...
# 1             utmapp /                 Virtual machines for iOS and macOS
# 2    NVIDIAGameWorks /  NVIDIA Kaolin Wisp is a PyTorch library powere...
# 3          microsoft /  The new Windows Terminal and the original Wind...
# 4            jina-ai /        Create Disco Diffusion artworks in one line
# 5      martinshkreli /                     stock market models - have fun
# 6   facebookresearch /  A framework for training and evaluating AI mod...
# 7       KalleHallden /  Curated list of public penetration test report...
# 8     juliocesarfort /               📚 Freely available programming books
# 9    EbookFoundation /   FauxPilot - an open-source GitHub Copilot server
# 10             moyix /  Lightweight full-featured WhatsApp Web + Multi...
# 11   josejesusguzman /  Open-source keyboard firmware for Atmel AVR an...
# ...

# %% [markdown]
# 6. Scrape the details of top 100 songs on billboard.com.
#
# Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome()
driver.maximize_window()

# %%
Url = "https://www.billboard.com/"
driver.get(Url)

# %%
Charts = driver.find_element(By.XPATH,"/html/body/div[3]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a")
Charts.click()

# %%
Hot=driver.find_element(By.XPATH,"/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a")
Hot.click()

# %%
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

song_name = driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[1]/h3[1]')
for i in song_name:
    if i.text is None :
        Song_name.append("--") 
    else:
        Song_name.append(i.text)

time.sleep(3)

artist_name = driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[1]/span")
for i in artist_name:
    if i.text is None:
        Artist_name.append("---")
    else:
        Artist_name.append(i.text)
time.sleep(3)

last_week_rank = driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[4]/span")
for i in last_week_rank:
    if i.text is None:
        Last_week_rank.append("---")
    else:
        Last_week_rank.append(i.text)
time.sleep(3)

peak_rank = driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[5]/span")
for i in peak_rank:
    if i.text is None:
        Peak_rank.append("---")
    else:
        Peak_rank.append(i.text)
time.sleep(3)

weeks_on_board = driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[6]/span")
for i in weeks_on_board:
    if i.text is None:
        Weeks_on_board.append("---")
    else:
        Weeks_on_board.append(i.text)
time.sleep(3)

# %%
Data_6=pd.DataFrame({'Song_name': Song_name,
                'Artist_name': Artist_name,
               'Last_week_rank': Last_week_rank,
                'Peak_rank': Peak_rank,
                'Weeks_on_board': Weeks_on_board})
Data_6
# Out:
#                                  Song_name                    Artist_name  \
# 0                          About Damn Time                          Lizzo
# 1                                As It Was                   Harry Styles
# 2   Running Up That Hill (A Deal With God)                      Kate Bush
# 3                              First Class                    Jack Harlow
# 4                               Wait For U  Future Featuring Drake & Tems
# ..                                     ...                            ...
# 95                             Te Felicito       Shakira & Rauw Alejandro
# 96                     Are You Entertained              Russ & Ed Sheeran
# 97            Bzrp Music Sessions, Vol. 52             Bizarrap & Quevedo
# 98                                Right On                       Lil Baby
# 99                            La Corriente          Bad Bunny & Tony Dize
#
#    Last_week_rank Peak_rank Weeks_on_board
# ...

# %% [markdown]
# Q7. Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
driver = webdriver.Chrome()
driver.maximize_window()
Url = 'https://www.naukri.com/data-science-recruiters-in-delhi-ncr'
driver.get(Url)

# %%
Name=[]
Designation=[]
Company=[]
Skills=[]
Location=[]

name = driver.find_elements(By.XPATH,'//p[@class="highlightable"]/a[1]/span')
for i in name:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)

time.sleep(3)        


designation = driver.find_elements(By.XPATH,'//p[@class="highlightable"]/span[1]')
for i in designation:
    if i.text is None :
        Designation.append("--") 
    else:
        Designation.append(i.text)
        
time.sleep(3)  


company = driver.find_elements(By.XPATH,'//p[@class="highlightable"]/a[2]')
for i in company:
    if i.text is None :
        Company.append("--") 
    else:
        Company.append(i.text)
        
time.sleep(3)  

skills = driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
for i in skills:
    if i.text is None :
        Skills.append("--") 
    else:
        Skills.append(i.text)
        
time.sleep(3)  

location = driver.find_elements(By.XPATH,'//p[@class="highlightable"]/span[2]')
for i in location:
    if i.text is None :
        Location.append("--") 
    else:
        Location.append(i.text)
nxt_button=driver.find_elements(By.XPATH,"//button[@class='grayBtn']")

# %%
Data_7 = pd.DataFrame({'Name': Name,
                'Designation': Designation,
               'Company': Company,
                'Skills': Skills,
                'Location': Location})
Data_7
# Out:
#                          Name                               Designation  \
# 0                Aakash Harit                                HR Manager
# 1             Vasundhara Kaul                         Company Recruiter
# 2                 Rajat Kumar                               Founder CEO
# 3        Rashmi Bhattacharjee                                   HR Head
# 4                       Rajni                 Team Leader HR Operations
# 5                Rajpal Tyagi                         Managing Director
# 6                  Urvi Kumar                          Talent Recruiter
# 7                Sanchit Garg                       Strategy Consultant
# 8                 Mamta rawat                       Technical Recruiter
# 9                 Mamta Rawat                       Technical Recruiter
# 10                     Aneela                           Management Head
# 11            Priyanka Balodi                                HR Analyst
# ...

# %% [markdown]
# Q8. Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
driver = webdriver.Chrome()
driver.maximize_window()
URL = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(URL)

# %%
Book_name=[]
Author_name=[]
Volume_sold=[]
Publisher=[]
Genre=[]
for i in range(1,101):
    
    book_name = driver.find_element(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr[{}]/td[2]'.format(i))
    Book_name.append(book_name.text)
    
    author_name = driver.find_element(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr[{}]/td[3]'.format(i))
    Author_name.append(author_name.text)
    
    volume_sold = driver.find_element(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr[{}]/td[4]'.format(i))
    Volume_sold.append(volume_sold.text)
    
    publisher = driver.find_element(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr[{}]/td[5]'.format(i))
    Publisher.append(publisher.text)
    
    genre = driver.find_element(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr[{}]/td[6]'.format(i))
    Genre.append(genre.text)

# %%
Data_8 = pd.DataFrame({'Book_name': Book_name,
                'Author_name': Author_name,
               'Volume_sold': Volume_sold,
                'Publisher': Publisher,
                'Genre': Genre})
Data_8
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume_sold        Publisher                        Genre
# ...

# %% [markdown]
# Q9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
driver = webdriver.Chrome()
driver.maximize_window()
Url = 'https://www.imdb.com/list/ls095964455/'
driver.get(Url)

# %%
Name=[]
Year_span=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]

name = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
for i in name:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)
        
time.sleep(3)  

year_span = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span[2]')
for i in year_span:
    if i.text is None :
        Year_span.append("--") 
    else:
        Year_span.append(i.text)
        
time.sleep(3)  

genre = driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[1]/span[5]')
for i in genre:
    if i.text is None :
        Genre.append("--") 
    else:
        Genre.append(i.text)
        
time.sleep(3)  

run_time = driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[1]/span[3]')
for i in run_time:
    if i.text is None :
        Run_time.append("--") 
    else:
        Run_time.append(i.text)
        
time.sleep(3)  

ratings = driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]/span[2]')
for i in ratings:
    if i.text is None :
        Ratings.append("--") 
    else:
        Ratings.append(i.text)
        
time.sleep(3)  

votes = driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[4]/span[2]')
for i in votes:
    if i.text is None :
        Votes.append("--") 
    else:
        Votes.append(i.text)

# %%
Data_9 = pd.DataFrame({'Name': Name,
                'Year_span': Year_span,
               'Genre': Genre,
                'Run_time': Run_time,
                'Ratings': Ratings,
                'Votes':Votes})
Data_9
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Ratings      Votes
# 0    57 min     9.2  2,020,928
# ...

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver = webdriver.Chrome()
driver.maximize_window()
Url = 'https://archive.ics.uci.edu/'
driver.get(Url)

# %%
search_button=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
search_button.click()
time.sleep(4)

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

Dataset_name=[]
dataset_name = driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]")
for i in dataset_name:
    if i.text is None :
        Dataset_name.append("--") 
    else:
        Dataset_name.append(i.text)
        

data_type = driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[2]/p')
for i in data_type:
    if i.text is None :
        Data_type.append("--") 
    else:
        Data_type.append(i.text)
        
time.sleep(3)


task = driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]')
for i in task:
    if i.text is None :
        Task.append("--") 
    else:
        Task.append(i.text)
        
time.sleep(3)  

attribute_type = driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[4]/p')
for i in attribute_type:
    if i.text is None :
        Attribute_type.append("--") 
    else:
        Attribute_type.append(i.text)
        
time.sleep(3)  

no_of_instances = driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[5]/p')
for i in no_of_instances: 
    if i.text is None :
        No_of_instances.append("--") 
    else:
        No_of_instances.append(i.text)
        
time.sleep(3)  

no_of_attribute= driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[6]/p')
for i in no_of_attribute:
    if i.text is None :
        No_of_attribute.append("--") 
    else:
        No_of_attribute.append(i.text)
time.sleep(3)

year= driver.find_elements(By.XPATH,'//table[@cellpadding="5"][1]/tbody/tr/td[7]/p')
for i in year:
    if i.text is None :
        Year.append("--") 
    else:
        Year.append(i.text)

# %%
Data_10 = pd.DataFrame({'Dataset_name':Dataset_name,'Data_type': Data_type, 
               'Task': Task,
                'Attribute_type': Attribute_type,
                'No_of_instances': No_of_instances,
                'No_of_attribute':No_of_attribute,'Year':Year})
                

Data_10
# Out:
#                                           Dataset_name  \
# 0                                                 Name
# 1                                              Abalone
# 2                                                Adult
# 3                                            Annealing
# 4                         Anonymous Microsoft Web Data
# ..                                                 ...
# 618    Influenza outbreak event prediction via Twit...
# 619                      Turkish Music Emotion Dataset
# 620                      Maternal Health Risk Data Set
# 621                          Room Occupancy Estimation
# 622    Image Recognition Task Execution Times in Mo...
#
#                       Data_type                  Task  \
# 0                    Data Types          Default Task
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                 Multivariate        Classification
# ...
